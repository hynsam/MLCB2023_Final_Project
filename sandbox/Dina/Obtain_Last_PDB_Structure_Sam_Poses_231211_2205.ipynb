# %%
#Process pdbs to get last structure
import glob

# %%
#Ref https://docs.python.org/3/library/glob.html
hf_out = "/Users/dsharon/Documents/MIT/6.8701/Project/Data/test_HarmonicFlow_timesplit_DistPock_rdkit_110epoch_save_inference_20231211_183902_2023-12-11_18-39-10/inference_output"
hf_last_write = "/Users/dsharon/Documents/MIT/6.8701/Project/Data/From_Sam_Last"
for pdbdir in glob.glob(f"{hf_out}/*"):
    #print(pdbdir)
    pdb_name = pdbdir.split("/")[-1]
    #print(pdb_name)
    pdb_fi = open(f"{pdbdir}/{pdb_name}_pred_0globalStep_xt.pdb", "r")
    endmdl_count = 0
    last_file = open(f"{hf_last_write}/{pdb_name}_x20.pdb", "w")
    for l in pdb_fi:
        if endmdl_count == 19:
            last_file.write(l)
        if l.rstrip() == "ENDMDL":
            endmdl_count += 1
    print(endmdl_count)
    last_file.close()
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# ...
